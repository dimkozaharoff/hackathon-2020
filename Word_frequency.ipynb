# %%
import pandas as pd
import nltk
from nltk import wordpunct_tokenize
import pymorphy2
import re
from sklearn.feature_extraction.text import CountVectorizer

# %%
stopWords = nltk.corpus.stopwords.words('Russian')

def tokenize(s):
    morph = pymorphy2.MorphAnalyzer()
    return [morph.parse(word)[0].normal_form for word in wordpunct_tokenize(s)]

# %%
def clear(el):
    return re.sub(r"[^\w ]", '', el).lower()

# %%
data_vacancies = pd.read_csv('vacancies.csv', sep=',', encoding='utf-8')
data_vacancies['description'] = data_vacancies['description'].apply(clear)

# %%
vectorizer = CountVectorizer(stop_words = stopWords, tokenizer=tokenize, ngram_range=(1, 3))

# %%
cv_fit = vectorizer.fit_transform(data_vacancies['description']).toarray()
# Out:
# D:\Users\maris\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['большой', 'весь', 'ещё', 'имя', 'мочь', 'нея', 'нибыть', 'ничто', 'свой', 'хороший', 'это'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-70-a845083f88e0> in <module>
# ----> 1 cv_fit = vectorizer.fit_transform(data_vacancies['description']).toarray()
#
# D:\Users\maris\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1022         if out is None and order is None:
#    1023             order = self._swap('cf')[0]
# -> 1024         out = self._process_toarray_args(order, out)
#    1025         if not (out.flags.c_contiguous or out.flags.f_contiguous):
# ...

# %%
data_vacancies['description'][0]
# Out:
# 'вакансия открыта в ооо норникель  общий центр обслуживания дочернее общество пао гмк норильский никель обязанности  обеспечение поддержки и сопровождение информационных biсистем в соответствии с соглашением об обслуживании sla анализ требований пользователей по развитию систем разработка спецификаций на настройку системы программ интерфейсов отчетов и тд настройка системы разработка дополнительной функциональности тестирование настроек актуализация и разработка регламентов проектных решений инструкций пользователя методических и нормативных материалов по процессам эксплуатации системы  требования  знание принципов проектирования хранилищ данных и систем аналитической отчетности опыт внедрения и или поддержки систем корпоративных хранилищ данных на базе sap bw с интеграцией с sap и не sap системамиисточниками от 2х лет опыт внедрения и или поддержки систем аналитической отчетности на базе sap business objects bi желателен опыт работы с sap bw on hana  условия  достойный уровень зараб
# ...

# %%
stat = pd.DataFrame([vectorizer.get_feature_names(), cv_fit.sum(axis=0)])
stat = stat.T
stat = stat.sort_values(1, axis=0, ascending = False)

# %%
stat.head(50)
# Out:
#                                   0      1
# 19953                     certified  24528
# 17261        blink javascriptдвижок  15005
# 14152      assemblers when required   9420
# 14350               atlassian 1 год   8631
# 12953             api разработка ui   8187
# 20202                    ci cd опыт   7551
# 21499                    club связь   7454
# 14675             awards продолжать   6762
# 10779                       amlриск   6719
# 16267               be соответствие   6269
# 19535                      cc javar   5929
# 12584                api jpa знание   5875
# 11644    android разработчик вместе   5504
# 11766                    angular js   5437
# 16858       bigdata team geekbrains   5321
# 23745          crm юридический лицо   5287
# 13973            as is формирование   5170
# 23318                   cpa cpo cac   5073
# 20718     cicdзнание gitопыт работа   4857
# 19449             cat аналитический   4627
# 19966                         ceter   4547
# ...
